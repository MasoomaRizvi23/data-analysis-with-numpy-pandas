# %%
import pandas as pd 
df_workers = pd.read_csv(r"C:\Users\masri\Downloads\income_data_Warm_Up.csv")
df_workers
# Out:
#                       Name                City  Age  Income  Experience
# 0               Haley Kirk        Bloemfontein   22   91650           2
# 1            Jordan Cooper              Dalian   56  114120          18
# 2           William Garcia            Changzhi   50  138319          22
# 3             Danny Bailey            Sorocaba   44   57164           0
# 4     Christopher Hamilton               Salta   46  109341          20
# ...                    ...                 ...  ...     ...         ...
# 5016            Patty Page             Cabinda   41  138731           8
# 5017        Carly Reynolds  Pingdingshan Henan   41  115185           9
# 5018          Tina Jimenez              Malaga   47  105630          28
# 5019        Matthew Norman               Zunyi   65  100347           5
# 5020        George Edwards               Kabul   50   93805          30
#
# [5021 rows x 5 columns]

# %%
#The average age of the workers in the data set, rounded down to the nearest integer?
int(df_workers["Age"].mean())
# Out:
# 41

# %%
#What is the most common age?
df_workers["Age"].mode()[0]
# Out:
# np.int64(51)

# %%
#How many people make at least 100,000 dollars a year?
(df_workers["Income"]>100000).sum()
# Out:
# np.int64(2539)

# %%
#How many people have between 20 and 30 years of experience (including both 20 and 30 years)?
((df_workers["Experience"] >= 20) & (df_workers["Experience"] <= 30)).sum()
# Out:
# np.int64(740)

# %%
#How many people have a last name beginning with the same letter as the city they live in? You may assume each name has exactly one space in it and your answer should be case sensitive.
