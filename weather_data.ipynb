# %%
import pandas as pd   
import numpy as np  
df_weather = pd.read_csv(r"C:\Users\masri\Downloads\CSV_FILES\weather_report.csv")
df_weather
# Out:
#             Date  Temperature  ...       Wind   Humidity
# 0     2025-08-30    21.493994  ...   6.929884  65.597477
# 1     2025-08-29    22.110711  ...  10.571807  74.085380
# 2     2025-08-28    22.129919  ...   8.700191  82.549158
# 3     2025-08-27    22.944873  ...   1.347219  87.096296
# 4     2025-08-26    17.090916  ...   9.858753  76.608902
# ...          ...          ...  ...        ...        ...
# 1019  2022-11-15    21.282755  ...  12.827782  42.190344
# 1020  2022-11-14    17.788899  ...  14.035854  85.572696
# 1021  2022-11-13    24.954408  ...  11.068915  62.742234
# 1022  2022-11-12    22.123296  ...   7.169169  78.451953
# 1023  2022-11-11    15.230198  ...  11.440779  49.587232
#
# [1024 rows x 6 columns]

# %%
df_final = df_weather.melt(
    id_vars = "Date",
    value_vars = df_weather.columns[1:],
    var_name = "Data", 
    value_name = "Measurement"
)
print(df_final)
# Out:
#             Date         data  Measurement
# 0     2025-08-30  Temperature    21.493994
# 1     2025-08-29  Temperature    22.110711
# 2     2025-08-28  Temperature    22.129919
# 3     2025-08-27  Temperature    22.944873
# 4     2025-08-26  Temperature    17.090916
# ...          ...          ...          ...
# 5115  2022-11-15     Humidity    42.190344
# 5116  2022-11-14     Humidity    85.572696
# 5117  2022-11-13     Humidity    62.742234
# 5118  2022-11-12     Humidity    78.451953
# 5119  2022-11-11     Humidity    49.587232
#
# [5120 rows x 3 columns]
