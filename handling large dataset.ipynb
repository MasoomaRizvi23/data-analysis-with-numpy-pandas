# %%
import numpy as np 
import pandas as pd    


#NORMAL OPTIMIZATION
df = pd.read_csv(r"C:\Users\masri\Downloads\CSV_FILES\6_0_track.csv")
print(df)
# Out:
#        Unnamed: 0             Name Country  Year       Event  Gender  \
# 0               0     Debra Dawson      PT  1960  100 metres    Male
# 1               1  Jennifer Norton      PH  1960  100 metres  Female
# 2               2  Jason Henderson      GB  1960  100 metres    Male
# 3               3    Deborah Marsh      CO  1960  100 metres  Female
# 4               4       Lydia Page      NL  1960  100 metres  Female
# ...           ...              ...     ...   ...         ...     ...
# 13389       13389   William Gordon      PK  2024    Marathon  Female
# 13390       13390   Barbara Phelps      NL  2024    Marathon    Male
# 13391       13391       Ray Sparks      DE  2024    Marathon  Female
# 13392       13392   Jessica Wilson      NG  2024    Marathon  Female
# 13393       13393      David Silva      IN  2024    Marathon  Female
#
#        Finish Time (s)
# 0                11.72
# 1                12.75
# 2                11.21
# 3                11.13
# ...

# %%
#Only load columns you need
df = pd.read_csv(r"C:\Users\masri\Downloads\CSV_FILES\6_0_track.csv", usecols=['Name', 'Year'])
print(df)
# Out:
#                   Name  Year
# 0         Debra Dawson  1960
# 1      Jennifer Norton  1960
# 2      Jason Henderson  1960
# 3        Deborah Marsh  1960
# 4           Lydia Page  1960
# ...                ...   ...
# 13389   William Gordon  2024
# 13390   Barbara Phelps  2024
# 13391       Ray Sparks  2024
# 13392   Jessica Wilson  2024
# 13393      David Silva  2024
#
# [13394 rows x 2 columns]

# %%
#Tell pandas what type each column is

df = pd.read_csv(r"C:\Users\masri\Downloads\CSV_FILES\6_0_track.csv", usecols=['Name', 'Year'], dtype={'Year': 'int32'})
print(df)
# Out:
#                   Name  Year
# 0         Debra Dawson  1960
# 1      Jennifer Norton  1960
# 2      Jason Henderson  1960
# 3        Deborah Marsh  1960
# 4           Lydia Page  1960
# ...                ...   ...
# 13389   William Gordon  2024
# 13390   Barbara Phelps  2024
# 13391       Ray Sparks  2024
# 13392   Jessica Wilson  2024
# 13393      David Silva  2024
#
# [13394 rows x 2 columns]

# %%
df = pd.read_csv(r"C:\Users\masri\Downloads\CSV_FILES\6_0_track.csv", nrows = 10)
print(df)
# Out:
#    Unnamed: 0             Name Country  Year       Event  Gender  \
# 0           0     Debra Dawson      PT  1960  100 metres    Male
# 1           1  Jennifer Norton      PH  1960  100 metres  Female
# 2           2  Jason Henderson      GB  1960  100 metres    Male
# 3           3    Deborah Marsh      CO  1960  100 metres  Female
# 4           4       Lydia Page      NL  1960  100 metres  Female
# 5           5     Eric Ramirez      AR  1960  100 metres  Female
# 6           6    Daniel Taylor      NG  1960  100 metres    Male
# 7           7        Kirk Hill      PE  1960  100 metres  Female
# 8           8      Molly Berry      LK  1960  100 metres    Male
# 9           9     Caleb Ramsey      KR  1960  100 metres    Male
#
#    Finish Time (s)
# 0            11.72
# 1            12.75
# 2            11.21
# 3            11.13
# 4            12.65
# 5            10.73
# 6            11.26
# 7            11.98
# 8            11.63
# 9            13.02

# %%
# Load in chunks (for very large files)

for chunk in pd.read_csv(r"C:\Users\masri\Downloads\CSV_FILES\6_0_track.csv", chunksize = 1000):
    
    print(chunk.shape)
# Out:
# (1000, 7)
# (1000, 7)
# (1000, 7)
# (1000, 7)
# (1000, 7)
# (1000, 7)
# (1000, 7)
# (1000, 7)
# (1000, 7)
# (1000, 7)
# (1000, 7)
# (1000, 7)
# (1000, 7)
# (394, 7)

# %%
#File is compressed? No problem


df= pd.read_csv(r"C:\Users\masri\Downloads\CSV_FILES\6_0_track.csv", compression = "gzip")
