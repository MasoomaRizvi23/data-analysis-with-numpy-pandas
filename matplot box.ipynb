# %%
import matplotlib.pyplot as plt  
import numpy as np 
import pandas as pd  


dfq = pd.DataFrame({
    "Name": [
        "Andrew Gonzales", "Mark Jenkins", "Sara Sullivan",
        "Gene Allen", "Adam Curry",
        # ... continue all names ...
        "David Medina", "Julia Jarvis", "Alicia Powers",
        "Theresa Daniel", "Helen Gallagher"
    ],
    "Quiz 1": [54.249839, 48.967157, 96.011224, 38.760431, 70.596130,
               # ...
               51.178104, 66.368140, 62.500947, 66.148486, 40.848941],
    "Quiz 2": [32.224177, 57.491389, 61.200334, 74.005167, 47.463208,
               # ...
               52.877461, 68.169914, 48.828656, 24.558999, 58.614020],
    # ...
    "Quiz 3": [68.173246, 49.801107, 48.996838, 74.849435, 57.282541,
               # ...
               63.423698, 73.209442, 61.959794, 74.351168, 64.120458],
    "Quiz 4": [70.638670, 39.212119, 71.755412, 58.597055, 59.953257,
               # ...
               69.123769, 58.343437, 49.763701, 59.979676, 58.643790],
    "Quiz 5": [75.570004, 74.761563, 72.865394, 61.349824, 64.191848,
               # ...
               98.309473, 58.023739, 93.567865, 74.573842, 48.444203]
})
print(dfq)
# Out:
#               Name     Quiz 1     Quiz 2     Quiz 3     Quiz 4     Quiz 5
# 0  Andrew Gonzales  54.249839  32.224177  68.173246  70.638670  75.570004
# 1     Mark Jenkins  48.967157  57.491389  49.801107  39.212119  74.761563
# 2    Sara Sullivan  96.011224  61.200334  48.996838  71.755412  72.865394
# 3       Gene Allen  38.760431  74.005167  74.849435  58.597055  61.349824
# 4       Adam Curry  70.596130  47.463208  57.282541  59.953257  64.191848
# 5     David Medina  51.178104  52.877461  63.423698  69.123769  98.309473
# 6     Julia Jarvis  66.368140  68.169914  73.209442  58.343437  58.023739
# 7    Alicia Powers  62.500947  48.828656  61.959794  49.763701  93.567865
# 8   Theresa Daniel  66.148486  24.558999  74.351168  59.979676  74.573842
# 9  Helen Gallagher  40.848941  58.614020  64.120458  58.643790  48.444203

# %%
plt.figure(figsize = (10,6))
plt.boxplot(dfq.drop("Name",axis =1).values,
           patch_artist = True,
           notch = True,
           vert = True, 
            boxprops = {'facecolor':'#00CC00', 'edgecolor':"black"}, 
            whiskers = {'color':'#4682B4', 'linewidth':1.5}, 
            flierprops = {'markerfacecolor':'#FF6347', 
                          'marker':'o', 'markersize':6}, 
            medianprops = {'color':"black", 'linewidth':2}
           
           )
plt.title('Box Plot for All Quizzes', fontsize=16)
plt.ylabel('Scores', fontsize=14)

plt.xticks(ticks=range(1, 9), 
           labels=[f'Quiz {i}' for i in range(1, 9)], 
           fontsize=12)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 plt.figure(figsize = (10,6))
# ----> 2 plt.boxplot(dfq.drop("Name",axis =1).values,
#       3            patch_artist = True,
#       4            notch = True,
#       5            vert = True,
#       6             boxprops = {'facecolor':'#00CC00', 'edgecolor':"black"},
#       7             whiskers = {'color':'#4682B4', 'linewidth':1.5},
#       8             flierprops = {'markerfacecolor':'#FF6347',
#       9                           'marker':'o', 'markersize':6},
#      10             medianprops = {'color':"black", 'linewidth':2}
#      11
#      12            )
#      13 plt.title('Box Plot for All Quizzes', fontsize=16)
#      14 plt.ylabel('Scores', fontsize=14)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\_api\deprecation.py:295, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     290     warn_deprecated(
#     291         since, message=f"The {old!r} parameter of {func.__name__}() "
#     292         f"has been renamed {new!r} since Matplotlib {since}; support "
#     293         f"for the old name will be dropped in %(removal)s.")
#     294     kwargs[new] = kwargs.pop(old)
# --> 295 return func(*args, **kwargs)
#
# TypeError: boxplot() got an unexpected keyword argument 'whiskers'
