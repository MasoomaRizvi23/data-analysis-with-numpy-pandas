# %%
import numpy as np

def diabetes_classification(blood_sugar_levels: np.ndarray[int|float]) \
    -> np.ndarray[str]:
  """
  Returns a converted array where each value in blood_sugar_levels
  is converted to a diabetes classification
  
  Examples:
     diabetes_classification(np.array([50, 120, 200])) => 
        np.array(["Normal", "Prediabetes", "Diabetes"])
        
     diabetes_classification(np.array([[125, 125.5], [126, 124.9]])) =>   
        np.array([['Diabetes', 'Diabetes'], ['Diabetes', 'Prediabetes']])
  """
  ##YOUR CODE GOES HERE
  # choices = ["Normal","prediabetes", "Diabetes"]
  # bins = [100,125]
  # indices = np.digitize(blood_sugar_levels, bins)
  # return np.array(choices)[indices]
  
  return np.where(blood_sugar_levels < 100, 'Normal',
           np.where(blood_sugar_levels < 125, 'Prediabetes',
                                              'Diabetes'))
  #test
levels = np.array([80, 110, 130, 99.9, 125, 100])
print(diabetes_classification(levels))
pass
# Out:
# ['Normal' 'Prediabetes' 'Diabetes' 'Normal' 'Diabetes' 'Prediabetes']
